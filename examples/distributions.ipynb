# %%
from birl.utils.distribution import *
import matplotlib.pyplot as plt

# %%
u = UniformDistribution(10, 20)
plt.hist(u.sample(10_000))
plt.show()

# %%
n = GaussianDistribution(0, 1) # standard normal distribution
plt.hist(n.sample(10_000))
plt.show()

# %%
l = LaplaceDistribution(0, 1)
plt.hist(l.sample(10_000))
plt.show()

# %%
b = BetaDistribution()
plt.hist(b.sample(10_000))
plt.show()
