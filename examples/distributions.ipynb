# %%
from birl.utils.distribution import UniformDistribution, NormalDistribution
import matplotlib.pyplot as plt

# %%
u = UniformDistribution(10, 20)
plt.hist(u.sample(10_000))
plt.show()

# %%
n = NormalDistribution(0, 1) # standard normal distribution
plt.hist(n.sample(10_000))
plt.show()
